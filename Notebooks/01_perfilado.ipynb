# %%
import pandas as pd
import numpy as np

# Cargar dataset
df = pd.read_csv("data/raw/dataset3_red_vial.csv", encoding="latin-1")

# -------------------------
# 1. Tipos de datos
# -------------------------
print("Tipos de datos:")
print(df.dtypes)

# -------------------------
# 2. Valores nulos
# -------------------------
nulos = df.isnull().sum()
porcentaje_nulos = (nulos / len(df)) * 100

print("\nValores nulos:")
print(pd.DataFrame({
 'Nulos': nulos,
 '% Nulos': porcentaje_nulos
}))

# -------------------------
# 3. Duplicados
# -------------------------
duplicados = df.duplicated().sum()
print(f"\nDuplicados: {duplicados}")

# -------------------------
# 4. Estadísticas descriptivas
# -------------------------
print("\nEstadísticas:")
print(df.describe())

# -------------------------
# 5. Outliers (IQR)
# -------------------------
numeric_df = df.select_dtypes(include=np.number)

Q1 = numeric_df.quantile(0.25)
Q3 = numeric_df.quantile(0.75)
IQR = Q3 - Q1

outliers = ((numeric_df < (Q1 - 1.5 * IQR)) | (numeric_df > (Q3 + 1.5 * IQR))).sum()

print("\nOutliers por columna:")
print(outliers)

# -------------------------
# 6. Categorías raras
# -------------------------
for col in df.select_dtypes(include='object'):
 print(f"\nCategorías en {col}:")
 print(df[col].value_counts(normalize=True).head())
# Out:
# Tipos de datos:
# ID                           int64
# ADMINIST                    object
# CODIGO_PEAJE                object
# DEPARTAMENTO                object
# NOMBRE_PEAJE                object
# VEH_LIGEROS_TAR_DIF          int64
# VEH_LIGEROS_AUTOMOVILES    float64
# VEH_PESADOS_TAR_DIF          int64
# VEH_PESADOS__2E            float64
# VEH_PESADOS_3E             float64
# VEH_PESADOS_4E             float64
# VEH_PESADOS_5E             float64
# VEH_PESADOS_6E             float64
# VEH_PESADOS_7E             float64
# VEH_LIGEROS_TOTAL            int64
# VEH_LIGEROS_IMD            float64
# VEH_PESADOS_TOTAL            int64
# VEH_PESADOS_IMD            float64
# VEH_TOTAL                    int64
# VEH_IMD                    float64
# ANIO                         int64
# MES                          int64
# PERIODO                      int64
# dtype: object
#
# Valores nulos:
#                          Nulos   % Nulos
# ID                           0  0.000000
# ADMINIST                     0  0.000000
# CODIGO_PEAJE                 0  0.000000
# DEPARTAMENTO                 0  0.000000
# NOMBRE_PEAJE                 0  0.000000
# VEH_LIGEROS_TAR_DIF          0  0.000000
# VEH_LIGEROS_AUTOMOVILES     13  0.120583
# VEH_PESADOS_TAR_DIF          0  0.000000
# VEH_PESADOS__2E              8  0.074205
# VEH_PESADOS_3E               8  0.074205
# VEH_PESADOS_4E               8  0.074205
# VEH_PESADOS_5E               8  0.074205
# VEH_PESADOS_6E               8  0.074205
# VEH_PESADOS_7E               8  0.074205
# VEH_LIGEROS_TOTAL            0  0.000000
# VEH_LIGEROS_IMD              0  0.000000
# VEH_PESADOS_TOTAL            0  0.000000
# VEH_PESADOS_IMD              0  0.000000
# VEH_TOTAL                    0  0.000000
# VEH_IMD                      0  0.000000
# ANIO                         0  0.000000
# MES                          0  0.000000
# PERIODO                      0  0.000000
#
# Duplicados: 0
#
# Estadísticas:
#                 ID  VEH_LIGEROS_TAR_DIF  VEH_LIGEROS_AUTOMOVILES  \
# count  10781.00000         10781.000000             10768.000000
# mean    5390.00000          1896.093034             44374.207467
# std     3112.35096          6297.010934             66000.775351
# min        0.00000             0.000000                 0.000000
# 25%     2695.00000             0.000000             11284.000000
# 50%     5390.00000             0.000000             23460.500000
# 75%     8085.00000           376.000000             47658.250000
# max    10780.00000         71734.000000            796486.000000
#
#        VEH_PESADOS_TAR_DIF  VEH_PESADOS__2E  VEH_PESADOS_3E  VEH_PESADOS_4E  \
# count         10781.000000     10773.000000    10773.000000    10773.000000
# mean            817.151841      8630.367586     7666.940685     1943.485287
# std            2710.769041     10942.912132     9845.497573     2608.109405
# min               0.000000         0.000000        0.000000        0.000000
# 25%               0.000000      2125.000000     1300.000000      309.000000
# 50%               0.000000      4218.000000     3573.000000      807.000000
# 75%               0.000000     10589.000000     8678.000000     2486.000000
# max           38818.000000     73590.000000    78943.000000    25137.000000
#
#        VEH_PESADOS_5E  VEH_PESADOS_6E  VEH_PESADOS_7E  VEH_LIGEROS_TOTAL  \
# count    10773.000000    10773.000000    10773.000000       10781.000000
# mean      2289.993874    11708.790495      162.748538       46216.792969
# std       3324.176873    16266.681390      391.491280       67003.821544
# min          0.000000        0.000000        0.000000           0.000000
# 25%        269.000000     1728.000000       12.000000       11870.000000
# 50%        808.000000     4172.000000       46.000000       24623.000000
# 75%       2817.000000    15900.000000      192.000000       50025.000000
# max      25361.000000    99895.000000    21799.000000      796486.000000
#
#        VEH_LIGEROS_IMD  VEH_PESADOS_TOTAL  VEH_PESADOS_IMD     VEH_TOTAL  \
# count     10781.000000       10781.000000     10781.000000  1.078100e+04
# mean       1521.112485       33195.434283      1092.216548  7.941223e+04
# std        2206.051192       41535.153871      1364.473182  9.904596e+04
# min           0.000000           0.000000         0.000000  0.000000e+00
# 25%         393.600000        7393.000000       244.200000  2.241400e+04
# 50%         811.100000       15964.000000       524.100000  4.208300e+04
# 75%        1644.200000       40611.000000      1335.700000  9.940700e+04
# max       27914.100000      241058.000000      8440.800000  1.037544e+06
#
#             VEH_IMD          ANIO           MES        PERIODO
# count  10781.000000  10781.000000  10781.000000   10781.000000
# mean    2613.362768   2019.339208      6.370281  201940.291068
# std     3258.058113      3.320685      3.448075     331.862137
# min        0.000000   2014.000000      1.000000  201401.000000
# 25%      739.000000   2016.000000      3.000000  201612.000000
# 50%     1390.200000   2019.000000      6.000000  201911.000000
# 75%     3282.100000   2022.000000      9.000000  202209.000000
# max    35023.400000   2025.000000     12.000000  202506.000000
#
# Outliers por columna:
# ID                            0
# VEH_LIGEROS_TAR_DIF        2255
# VEH_LIGEROS_AUTOMOVILES    1123
# VEH_PESADOS_TAR_DIF        2516
# VEH_PESADOS__2E            1045
# VEH_PESADOS_3E             1387
# VEH_PESADOS_4E             1125
# VEH_PESADOS_5E             1141
# VEH_PESADOS_6E             1006
# VEH_PESADOS_7E             1004
# VEH_LIGEROS_TOTAL          1159
# VEH_LIGEROS_IMD            1171
# VEH_PESADOS_TOTAL          1192
# VEH_PESADOS_IMD            1195
# VEH_TOTAL                  1002
# VEH_IMD                     998
# ANIO                          0
# MES                           0
# PERIODO                       0
# dtype: int64
#
# Categorías en ADMINIST:
# ADMINIST
# Concesionado       0.688155
# No concesionado    0.311845
# Name: proportion, dtype: float64
#
# Categorías en CODIGO_PEAJE:
# CODIGO_PEAJE
# 13PE08CDS1     0.013913
# 13PE10AMEO1    0.013913
# 04PE1SCAM1     0.012800
# 12PE3NCRA1     0.012800
# 15PE1SCLA1     0.012800
# Name: proportion, dtype: float64
#
# Categorías en DEPARTAMENTO:
# DEPARTAMENTO
# Puno           0.112049
# Lima           0.110750
# Arequipa       0.100826
# Piura          0.089509
# La Libertad    0.066228
# Name: proportion, dtype: float64
#
# Categorías en NOMBRE_PEAJE:
# NOMBRE_PEAJE
# Ciudad de Dios           0.013913
# Menocucho (Quirihuac)    0.013913
# Camaná                   0.012800
# Casaracra-Concesión      0.012800
# Chilca                   0.012800
# Name: proportion, dtype: float64
